# %% [markdown]
# Imports

# %%
# %pip install pretty_midi
# %pip install --upgrade pyfluidsynth
# Out:
# Requirement already satisfied: pretty_midi in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (from pretty_midi) (2.2.3)
# Requirement already satisfied: mido>=1.1.16 in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: six in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: packaging in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (from mido>=1.1.16->pretty_midi) (24.2)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyfluidsynth in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy in c:\users\pferdlexxie\documents\genai\genai\lib\site-packages (from pyfluidsynth) (2.2.3)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import collections
import fluidsynth
import glob
import pretty_midi
from IPython import display
from typing import Dict, List, Optional, Sequence, Tuple

# %% [markdown]
# Work with midi

# %%
sample_rate = 44100

def play_audio(midi_object, duration=30):
    audio_waveform = midi_object.fluidsynth(fs=sample_rate)
    trimmed_waveform = audio_waveform[:duration * sample_rate]
    return display.Audio(trimmed_waveform, rate=sample_rate)

midi_object = pretty_midi.PrettyMIDI()

piano = pretty_midi.Instrument(program=0, is_drum=False, name="Acoustic Grand Piano")
midi_object.instruments.append(piano)

# %%
def extract_midi_notes(midi_path):
    midi_data = pretty_midi.PrettyMIDI(midi_path)

    if not midi_data.instruments:
        print(f"Warning: No instruments found in {midi_path}!")
        return pd.DataFrame()  
    main_instrument = midi_data.instruments[0]  
    if not main_instrument.notes:
        print(f"Warning: No notes found in {midi_path}!")
        return pd.DataFrame()

    note_info = collections.defaultdict(list)
    ordered_notes = sorted(main_instrument.notes, key=lambda n: n.start)
    previous_start = ordered_notes[0].start if ordered_notes else 0

    for n in ordered_notes:
        start_time = n.start
        end_time = n.end
        note_info["pitch"].append(n.pitch)
        note_info["start"].append(start_time)
        note_info["end"].append(end_time)
        note_info["step"].append(start_time - previous_start)
        note_info["duration"].append(end_time - start_time)
        previous_start = start_time

    return pd.DataFrame({key: np.array(value) for key, value in note_info.items()})

# %% [markdown]
# Load data

# %%
filenames = glob.glob('music-midi-dataset/midi_dataset/midi_dataset/*.mid')

# %%
num_files = 50 
all_notes = []

for f in filenames[:num_files]:
    print(f"Processing: {f}")
    try:
        notes = extract_midi_notes(f)
        if notes.empty:
            print(f"Warning: {f} produced an empty DataFrame!")
        else:
            all_notes.append(notes)
    except Exception as e:
        print(f"Error processing {f}: {e}")
# Out:
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (1).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (10).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (11).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (12).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (13).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (14).mid
# c:\Users\pferdlexxie\Documents\GenAI\genai\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (15).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (16).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (17).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (18).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (19).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (2).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (20).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (21).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (22).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (23).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (24).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (25).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (26).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (27).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (28).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (29).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (3).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (30).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (31).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (32).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (33).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (34).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (35).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (36).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (37).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (38).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (39).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (4).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (40).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (41).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (42).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (43).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (44).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (45).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (46).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (47).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (48).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (49).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (5).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (50).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (6).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (7).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (8).mid
# Processing: music-midi-dataset/midi_dataset/midi_dataset\x (9).mid

# %%
if all_notes:
    all_notes = pd.concat(all_notes, ignore_index=True)
    print("Final Processed Notes DataFrame:")
    print(all_notes.head()) 
else:
    print("No valid MIDI files processed!")

if not all_notes.empty:
    note_names = np.vectorize(pretty_midi.note_number_to_name)
    sample_note_names = note_names(all_notes["pitch"])
    print("Sample Note Names:", sample_note_names[:10])
# Out:
# Final Processed Notes DataFrame:
#    pitch  start  end  step  duration
# 0     67    0.0  2.0   0.0       2.0
# 1     64    0.0  2.0   0.0       2.0
# 2     59    0.0  2.0   0.0       2.0
# 3     71    2.0  4.0   2.0       2.0
# 4     55    2.0  4.0   0.0       2.0
# Sample Note Names: ['G4' 'E4' 'B3' 'B4' 'G3' 'G4' 'G4' 'E4' 'C4' 'G3']

# %% [markdown]
# Generate music

# %%
def notes_to_midi(
    notes: pd.DataFrame,
    out_file: str,
    instrument_name: str,
    velocity: int = 100, 
) -> pretty_midi.PrettyMIDI:
    pm = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(
        program=pretty_midi.instrument_name_to_program(instrument_name))

    prev_start = 0
    for _, note in notes.iterrows():
        start = float(prev_start + note['step'])
        end = float(start + note['duration'])
        midi_note = pretty_midi.Note(
            velocity=velocity,
            pitch=int(note['pitch']),
            start=start,
            end=end,
        )
        instrument.notes.append(midi_note)
        prev_start = start

    pm.instruments.append(instrument)
    pm.write(out_file)
    return pm

if not all_notes.empty:
    output_midi = "generated_music.mid"
    notes_to_midi(all_notes, output_midi, "Acoustic Grand Piano")

if not all_notes.empty:
    key_order = ["pitch", "step", "duration"]
    train_notes = np.stack([all_notes[key] for key in key_order], axis=1)

    notes_ds = tf.data.Dataset.from_tensor_slices(train_notes)

# %% [markdown]
# Sequences

# %%
seq_length = 20
vocab_size = 128

def create_sequences(dataset, seq_length, vocab_size=128):
    sequences = []
    targets = []
    num_seq = dataset.shape[0] - seq_length 

    for i in range(num_seq):
        sequence = dataset[i:i + seq_length, :] / [vocab_size, 1, 1]  
        target = dataset[i + seq_length, :] / [vocab_size, 1, 1]  
        sequences.append(sequence)
        targets.append(target)

    sequences = np.array(sequences)
    targets = np.array(targets)
    
    print(sequences.shape, targets.shape) 

    tf_dataset = tf.data.Dataset.from_tensor_slices(
        (sequences, {"pitch": targets[:, 0], "step": targets[:, 1], "duration": targets[:, 2]})
    )
    
    return tf_dataset

seq_ds = create_sequences(train_notes, seq_length, vocab_size)

batch_size = 64
buffer_size = 5000

train_ds = seq_ds.shuffle(buffer_size).batch(batch_size)

print(train_ds.element_spec)
# Out:
# (6938, 20, 3) (6938, 3)
# (TensorSpec(shape=(None, 20, 3), dtype=tf.float64, name=None), {'pitch': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'step': TensorSpec(shape=(None,), dtype=tf.float64, name=None), 'duration': TensorSpec(shape=(None,), dtype=tf.float64, name=None)})

# %% [markdown]
# LSTM model

# %%
layer = tf.keras.layers
learning_rate = 0.005
input_data = tf.keras.Input(shape=(seq_length , 3))
x= layer.LSTM(128)(input_data)
outputs = {
    "pitch":tf.keras.layers.Dense(64 , name = "pitch")(x),
    "step":tf.keras.layers.Dense(1 , name = "step")(x),
    "duration":tf.keras.layers.Dense(1 , name = "duration")(x),
}
model = tf.keras.Model(input_data , outputs)

loss  ={
    "pitch" : tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    "step": tf.keras.losses.MeanSquaredError(),
    "duration":tf.keras.losses.MeanSquaredError(),
}
optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate)
model.compile(loss=loss ,    loss_weights={
        'pitch': 0.05,
        'step': 1.0,
        'duration':1.0,
    }, optimizer = optimizer)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 20, 3)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 128)       │     67,584 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ duration (Dense)    │ (None, 1)         │        129 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pitch (Dense)       │ (None, 64)        │      8,256 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ step (Dense)        │ (None, 1)         │        129 │ lstm[0][0]        │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 76,098 (297.26 KB)
#  Trainable params: 76,098 (297.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_ds , epochs = 50)

hist = model.predict(train_ds)
print(hist["duration"].shape)
# Out:
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0273 - loss: 1.5467 - pitch_loss: 0.0270 - step_loss: 1.5177
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0247 - loss: 3.3053 - pitch_loss: 0.0290 - step_loss: 3.2788
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0261 - loss: 1.5524 - pitch_loss: 0.0112 - step_loss: 1.5254
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0243 - loss: 2.0444 - pitch_loss: 0.0125 - step_loss: 2.0191
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0286 - loss: 2.0386 - pitch_loss: 0.0040 - step_loss: 2.0094
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0264 - loss: 8.5531 - pitch_loss: 0.0019 - step_loss: 8.5263
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0235 - loss: 4.9724 - pitch_loss: 0.0044 - step_loss: 4.9483
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0240 - loss: 1.2617 - pitch_loss: 0.0043 - step_loss: 1.2372
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0227 - loss: 5.0850 - pitch_loss: 0.0027 - step_loss: 5.0619
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0219 - loss: 8.2388 - pitch_loss: 0.0032 - step_loss: 8.2164
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - duration_loss: 0.0225 - loss: 1.6116 - pitch_loss: 0.0021 - step_loss: 1.5887
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - duration_loss: 0.0221 - loss: 7.3633 - pitch_loss: 0.0038 - step_loss: 7.3407
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - duration_loss: 0.0214 - loss: 6.0318 - pitch_loss: 0.0033 - step_loss: 6.0102
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0217 - loss: 4.4715 - pitch_loss: 0.0042 - step_loss: 4.4493
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0219 - loss: 1.6984 - pitch_loss: 0.0025 - step_loss: 1.6760
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0225 - loss: 2.8707 - pitch_loss: 0.0031 - step_loss: 2.8477
# Epoch 17/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0229 - loss: 2.1515 - pitch_loss: 0.0030 - step_loss: 2.1281
# Epoch 18/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0240 - loss: 2.2894 - pitch_loss: 0.0022 - step_loss: 2.2650
# Epoch 19/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - duration_loss: 0.0241 - loss: 6.5204 - pitch_loss: 0.0019 - step_loss: 6.4959
# Epoch 20/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - duration_loss: 0.0203 - loss: 1.6381 - pitch_loss: 0.0016 - step_loss: 1.6174
# Epoch 21/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0205 - loss: 12.1746 - pitch_loss: 0.0021 - step_loss: 12.1536
# Epoch 22/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0188 - loss: 1.0098 - pitch_loss: 0.0016 - step_loss: 0.9905
# Epoch 23/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0232 - loss: 1.4153 - pitch_loss: 0.0014 - step_loss: 1.3917
# Epoch 24/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0189 - loss: 2.2887 - pitch_loss: 0.0013 - step_loss: 2.2694
# Epoch 25/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0199 - loss: 0.9481 - pitch_loss: 0.0017 - step_loss: 0.9278
# Epoch 26/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0267 - loss: 4.6034 - pitch_loss: 0.0017 - step_loss: 4.5762
# Epoch 27/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0203 - loss: 1.0546 - pitch_loss: 0.0012 - step_loss: 1.0339
# Epoch 28/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0194 - loss: 3.6753 - pitch_loss: 0.0022 - step_loss: 3.6554
# Epoch 29/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0215 - loss: 7.5815 - pitch_loss: 0.0016 - step_loss: 7.5596
# Epoch 30/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0294 - loss: 6.5381 - pitch_loss: 4.6440e-04 - step_loss: 6.5083
# Epoch 31/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0240 - loss: 1.1674 - pitch_loss: 4.3941e-04 - step_loss: 1.1431
# Epoch 32/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0242 - loss: 0.8593 - pitch_loss: 9.6934e-04 - step_loss: 0.8347
# Epoch 33/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0241 - loss: 6.1657 - pitch_loss: 6.9755e-04 - step_loss: 6.1412
# Epoch 34/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0218 - loss: 2.8258 - pitch_loss: 5.0216e-04 - step_loss: 2.8037
# Epoch 35/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0200 - loss: 1.4848 - pitch_loss: 8.1002e-04 - step_loss: 1.4645
# Epoch 36/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0198 - loss: 2.5644 - pitch_loss: 6.7735e-04 - step_loss: 2.5443
# Epoch 37/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0226 - loss: 0.8895 - pitch_loss: 5.7147e-04 - step_loss: 0.8665
# Epoch 38/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0239 - loss: 0.4674 - pitch_loss: 5.2305e-04 - step_loss: 0.4432
# Epoch 39/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - duration_loss: 0.0219 - loss: 0.6929 - pitch_loss: 9.5960e-04 - step_loss: 0.6706
# Epoch 40/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0204 - loss: 1.1831 - pitch_loss: 5.4859e-04 - step_loss: 1.1624
# Epoch 41/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0223 - loss: 0.9229 - pitch_loss: 5.9853e-04 - step_loss: 0.9003
# Epoch 42/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0249 - loss: 1.3095 - pitch_loss: 3.3239e-04 - step_loss: 1.2843
# Epoch 43/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0221 - loss: 0.9564 - pitch_loss: 9.3144e-04 - step_loss: 0.9339
# Epoch 44/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0374 - loss: 0.7859 - pitch_loss: 1.5803e-05 - step_loss: 0.7482
# Epoch 45/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0248 - loss: 1.1876 - pitch_loss: 1.5252e-05 - step_loss: 1.1624
# Epoch 46/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0227 - loss: 1.9780 - pitch_loss: 3.9390e-05 - step_loss: 1.9550
# Epoch 47/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0237 - loss: 2.4545 - pitch_loss: 1.8544e-04 - step_loss: 2.4304
# Epoch 48/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0234 - loss: 1.7943 - pitch_loss: 1.7606e-04 - step_loss: 1.7705
# Epoch 49/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0241 - loss: 0.4985 - pitch_loss: 4.8724e-05 - step_loss: 0.4741
# Epoch 50/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - duration_loss: 0.0197 - loss: 6.8480 - pitch_loss: 1.4073e-04 - step_loss: 6.8279
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# (6938, 1)

# %% [markdown]
# Generate notes

# %%
def predict_next_note(notes, keras_model, temperature):
    assert temperature > 0, "Temperature must be greater than zero."
    
    inputs = np.expand_dims(notes, 0)
    predictions = keras_model.predict(inputs)

    pitch_logits = predictions["pitch"] 
    step = predictions["step"] 
    duration = predictions["duration"]  

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

temperature = 2.0
num_predictions = int(10 / 0.25)

sample_notes = np.stack([all_notes[key] for key in key_order], axis=1)
input_notes = sample_notes[:seq_length] / np.array([vocab_size, 1, 1])

generated_notes = []
prev_start = 0

for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    
    generated_notes.append((*input_note, start, end))
    
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    
    prev_start = start

generated_notes = pd.DataFrame(
    generated_notes, columns=(*key_order, "start", "end"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# See music

# %%
out_file = 'generated.mid'  

instrument_name = "Acoustic Grand Piano"  

out_pm = notes_to_midi(
    generated_notes, out_file=out_file, instrument_name=instrument_name)

print(f"Generated MIDI file saved as: {out_file}")

play_audio(out_pm, duration=10)
# Out:
# Generated MIDI file saved as: generated.mid
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
